# %%
#import libs 
from dotenv import load_dotenv
from openai import OpenAI
import os
import json
load_dotenv(override=True)
from IPython.display import Markdown, display

# %%
openai = OpenAI()

# %%
content = "give me a problem or task that can be solved by creating an agent with a couple of internal tools. Only return the task/problem."
messages = [{"role": "user", "content": content}]

response = openai.chat.completions.create(
    model="gpt-4o-mini",
    messages = messages
)

answer = response.choices[0].message.content

display(Markdown(answer))
# Out:
# Design a virtual personal assistant that can manage a user’s calendar, schedule meetings, and send reminders, while also providing recommendations for optimal meeting times based on participants' availability and preferences.

# %%
from rich.console import Console 

def show(text):
    try:
        Console().print(text)
    except Exception:
        print(text)
